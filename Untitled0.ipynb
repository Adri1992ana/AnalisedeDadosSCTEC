# %% [markdown]
# <a href="https://colab.research.google.com/github/Adri1992ana/AnalisedeDadosSCTEC/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Criar arquivo README.md no Colab


with open("README.md", "w") as f:
    f.write("""
# 📄 Projeto Titanic

## 1. Introdução
Este projeto tem como objetivo analisar o famoso dataset do Titanic, utilizando Python e bibliotecas de ciência de dados. A atividade prática envolve carregar os dados, realizar análises exploratórias, gerar visualizações gráficas e documentar os principais insights obtidos.

---

## 2. Estrutura do Projeto
- **Notebook (Colab/Jupyter)** com código em Python.
- **Dataset Titanic** carregado via link corrigido do Google Drive.
- **Gráficos salvos em `.png`** na pasta `graficos/`.
- **Documentação (README)** com explicações e conclusões.

---

## 3. Etapas Realizadas
1. **Importação de bibliotecas**: Pandas, Seaborn e Matplotlib.
2. **Carregamento dos dados**: leitura do CSV via link direto (`uc?id=...`).
3. **Exploração inicial**: uso de `df.info()`, `df.describe()` e verificação de valores nulos.
4. **Tratamento de dados nulos**: análise da coluna `Age` e decisão de preenchimento ou remoção.
5. **Criação de gráficos**:
   - Sobrevivência por sexo.
   - Sobrevivência por classe.
   - Taxa de sobrevivência geral.
6. **Salvamento dos gráficos** em `.png` para entrega.
7. **Conclusões documentadas** no README.

---

## 4. Visualizações
- **Gráfico 1 – Sobrevivência por Sexo**
  Mostra que mulheres tiveram maior taxa de sobrevivência em comparação aos homens.

- **Gráfico 2 – Sobrevivência por Classe**
  Passageiros da 1ª classe sobreviveram mais, enquanto os da 3ª classe tiveram menor taxa de sobrevivência.

- **Gráfico 3 – Taxa de Sobrevivência Geral**
  Indica que a maioria dos passageiros não sobreviveu ao naufrágio.

---

## 5. Conclusões
- O dataset apresenta valores nulos, especialmente na coluna `Age`, que foram tratados para garantir consistência.
- Mulheres e passageiros da 1ª classe tiveram maior taxa de sobrevivência.
- Homens e passageiros da 3ª classe foram os mais afetados pelo naufrágio.
- A taxa geral de sobrevivência mostra que a maioria dos passageiros não conseguiu escapar.
- As visualizações gráficas reforçam os padrões históricos conhecidos do desastre do Titanic.

---

## 6. Organização da Entrega
- Pasta `notebook/` → contém o código em Python.
- Pasta `dataset/` → contém o arquivo Titanic CSV.
- Pasta `graficos/` → contém os arquivos `.png` dos gráficos.
- Arquivo `README.md` → documentação final com mais de 800 caracteres.

""")
