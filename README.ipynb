# %% [markdown]
# <a href="https://colab.research.google.com/github/Adri1992ana/AnalisedeDadosSCTEC/blob/main/README.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Criar o arquivo README.md com conteúdo

conteudo = """
# DesafioExtra: Analise de Dados do Titanic

## 1. Introdução

Este projeto foi desenvolvido como atividade prática extra do curso Introdução ao Data Science (IP 20h A), utilizando Python e bibliotecas de ciência de dados. A atividade prática envolve carregar os dados, realizar análises exploratórias, gerar visualizações gráficas e documentar os principais insights obtidos.


## 2. Estrutura do Projeto

- Notebook (Colab/Jupyter) com código em Python.
- Dataset Titanic carregada a partir de um arquivo CSV disponibilizado pelo curso.
- Gráficos salvos em `.png` na pasta `graficos/`.
- Documentação (README) com explicações e conclusões.

## 3. Etapas Realizadas

Passo 1. Importação de bibliotecas: Pandas, Seaborn e Matplotlib.
Passo 2. Carregamento dos dados: leitura do CSV via link direto (`uc?id=...`).
Passo 3. Exploração inicial: uso de df.info(), df.describe() e verificação de valores nulos.
Passo 4. Tratamento de dados nulos: análise da coluna Age e decisão de preenchimento ou remoção.
Passo 5. Criação de gráficos:
   - Sobrevivência por sexo.
   - Sobrevivência por classe.
   - Taxa de sobrevivência geral.
Passo 6. Salvei os gráficos em `.png` para entregar.
Passo 7. Conclusões documentadas através do README.

## 4. Visualizações gráficas

- Gráfico 1 – Sobrevivência por Sexo: Mostra que as mulheres tiveram maior taxa de sobrevivência em comparação aos homens.
- Gráfico 2 – Sobrevivência por Classe: Passageiros da 1ª classe sobreviveram mais, enquanto os da 3ª classe tiveram menor taxa de sobrevivência.
- Gráfico 3 – Taxa de Sobrevivência Geral: Indica que a maioria dos passageiros não sobreviveu ao naufrágio do navio.

## 5. Conclusões

- O dataset apresentava valores nulos, especialmente na coluna Age.
- Mulheres e passageiros da 1ª classe tiveram maior taxa de sobrevivência.
- Homens e passageiros da 3ª classe foram os mais afetados pelo desastre.
- A taxa geral de sobrevivência mostrou que a maioria dos passageiros não conseguiram sobreviver.
- As visualizações reforçam os padrões históricos conhecidos desse famoso desastre do navio TITANIC.

## 6. Organização da Entrega

- Pasta codigo/ : contém o código em Python (Analise_Titanic.ipynb).
- Pasta dados/ : contém o arquivo Titanic CSV.
- Pasta graficos/ : contém os arquivos `.png`.
- Arquivo README.md : documentação final do desafio.
"""

# Escreve o conteúdo no arquivo README.md
with open("README.md", "w") as f:
    f.write(conteudo)

# %%
# !ls -l README.md
# Out:
# -rw-r--r-- 1 root root 1868 Mar 27 22:59 README.md

# %%
from google.colab import files
files.download("README.md")
